# %% [markdown]
# # Game of "Functions"

# %% [markdown]
# Assignment 3 : Functions | Modules
#
# Question 1
#
# Write a Python function to sum all the numbers in a list.
#
# Sample List : (8, 2, 3, 0, 7)
#
# Expected Output : 20
#
# Explanation:
#
# Summation should like 8+2+3+0+7 = 20

# %%
def adding():
    list1 = eval(input('Enter the list for Addition : '))
    total_sum = 0
    for numbers in list1:
        total_sum = total_sum + numbers
    return(total_sum)
total_sum = adding()
print('Addition of Entered List is : ' , total_sum )
# Out:
# Enter the list for Addition : 15,35,40.25,45.41,20.18
# Addition of Entered List is :  155.84
